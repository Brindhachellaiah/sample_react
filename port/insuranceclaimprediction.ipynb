# %%
#Importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#importing dataset
df = pd.read_csv('pc-sg.csv')
#df1 =  pd.read_csv('../input/sample-insurance-claim-prediction-dataset/insurance2.csv')

# %%
df.head(3)
# Out:
#           Port  Year  Week Commercial Market Commercial Size Class  \
# 0  Tanah merah  2022    24               ALL                   ALL
# 1    Singapore  2022    24               ALL                   ALL
# 2       Changi  2022    24               ALL                   ALL
#
#    Median Waiting Time Off Port Limits  \
# 0                                  0.9
# 1                                  0.9
# 2                                  0.1
#
#   Waiting Time Off Port Limits Confidence Score   Median Time At Port  \
# 0                                           HIGH                  0.0
# 1                                           HIGH                  0.8
# 2                                         MEDIUM                  0.8
#
#   Time At Port Confidence Score  \
# 0                          HIGH
# 1                          HIGH
# 2                        MEDIUM
#
#    Median Waiting Time Off Port Limits  Standard Deviation   \
# ...

# %%
#df1.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
#Checking for null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (146, 19)

# %%
df.describe()
# Out:
#               Year        Week  Median Waiting Time Off Port Limits  \
# count   146.000000  146.000000                           141.000000
# mean   2021.465753   26.856164                             0.901418
# std       0.500543   15.406667                             0.708316
# min    2021.000000    1.000000                             0.000000
# 25%    2021.000000   13.250000                             0.400000
# 50%    2021.000000   27.500000                             0.800000
# 75%    2022.000000   40.000000                             1.200000
# max    2022.000000   52.000000                             3.700000
#
#        Median Time At Port  \
# count           146.000000
# mean              0.565753
# std               0.363401
# min               0.000000
# 25%               0.100000
# 50%               0.800000
# 75%               0.800000
# max               0.900000
#
#        Median Waiting Time Off Port Limits  Standard Deviation   \
# ...

# %%
df.dtypes
# Out:
# Port                                                              object
# Year                                                               int64
# Week                                                               int64
# Commercial Market                                                 object
# Commercial Size Class                                             object
# Median Waiting Time Off Port Limits                              float64
# Waiting Time Off Port Limits Confidence Score                     object
# Median Time At Port                                              float64
# Time At Port Confidence Score                                     object
# Median Waiting Time Off Port Limits  Standard Deviation          float64
# Time At Port Standard Deviation                                  float64
# Median Waiting Time Off Port Limits Difference (week-to-week)    float64
# Waiting Time Off Port Limits  % Difference (week-to-week)        float64
# ...

# %%
df['Waiting Time Off Port Limits Confidence Score '].unique()
# Out:
# array(['HIGH', 'MEDIUM', 'LOW'], dtype=object)

# %%
sns.countplot(x='Waiting Time Off Port Limits Confidence Score ',hue='Port',data=df)
# Out:
# <AxesSubplot:xlabel='Waiting Time Off Port Limits Confidence Score ', ylabel='count'>

# %%
sns.countplot(x='Time At Port Confidence Score',hue='Port',data=df)
# Out:
# <AxesSubplot:xlabel='Time At Port Confidence Score', ylabel='count'>

# %%
sns.countplot(x='Port',hue='Number Of Vessels',data=df)
# Out:
# <AxesSubplot:xlabel='Port', ylabel='count'>

# %%
sns.countplot(x='Port',hue='Number Of Calls',data=df)
# Out:
# <AxesSubplot:xlabel='Port', ylabel='count'>

# %%
x = df['Median Waiting Time Off Port Limits']
sns.distplot(x)
# Out:
# <AxesSubplot:xlabel='Median Waiting Time Off Port Limits', ylabel='Density'>

# %%
x = df['Median Time At Port']
sns.distplot(x)
# Out:
# <AxesSubplot:xlabel='Median Time At Port', ylabel='Density'>

# %%
#Plotting correlation
corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(14,8))
#To plot heatmap
import seaborn as sns
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.head(2)
# Out:
#           Port  Year  Week Commercial Market Commercial Size Class  \
# 0  Tanah merah  2022    24               ALL                   ALL
# 1    Singapore  2022    24               ALL                   ALL
#
#    Median Waiting Time Off Port Limits  \
# 0                                  0.9
# 1                                  0.9
#
#   Waiting Time Off Port Limits Confidence Score   Median Time At Port  \
# 0                                           HIGH                  0.0
# 1                                           HIGH                  0.8
#
#   Time At Port Confidence Score  \
# 0                          HIGH
# 1                          HIGH
#
#    Median Waiting Time Off Port Limits  Standard Deviation   \
# 0                                                0.4
# 1                                                4.2
#
#    Time At Port Standard Deviation  \
# 0                              0.1
# 1                              3.8
#
# ...

# %%
df = df.drop(['Commercial Market','Commercial Size Class','Unlocode','Median Waiting Time Off Port Limits  Standard Deviation ','Time At Port Standard Deviation'],axis =1) # dropping the unncessary column
df.head(2)
# Out:
#           Port  Year  Week  Median Waiting Time Off Port Limits  \
# 0  Tanah merah  2022    24                                  0.9
# 1    Singapore  2022    24                                  0.9
#
#   Waiting Time Off Port Limits Confidence Score   Median Time At Port  \
# 0                                           HIGH                  0.0
# 1                                           HIGH                  0.8
#
#   Time At Port Confidence Score  \
# 0                          HIGH
# 1                          HIGH
#
#    Median Waiting Time Off Port Limits Difference (week-to-week)  \
# 0                                               -0.1
# 1                                                0.1
#
#    Waiting Time Off Port Limits  % Difference (week-to-week)  \
# 0                                              -10.0
# 1                                               12.5
#
#    Time At Port Difference (week-to-week)  \
# 0                                     0.0
# ...

# %%
# replacing values
df['Port'].replace(['Tanah merah', 'Singapore','Changi'],[0, 1,2], inplace=True)
df['Waiting Time Off Port Limits Confidence Score '].replace(['HIGH', 'MEDIUM','LOW'],[2, 1,0], inplace=True)
df['Time At Port Confidence Score'].replace(['HIGH', 'MEDIUM','LOW'],[2, 1,0], inplace=True)

# %%
df = df.drop(['Port Country'],axis =1)

# %%
df.shape
# Out:
# (146, 13)

# %%
df.isna().apply(pd.value_counts)
# Out:
#         Port   Year   Week  Median Waiting Time Off Port Limits  \
# False  146.0  146.0  146.0                                  141
# True     NaN    NaN    NaN                                    5
#
#        Waiting Time Off Port Limits Confidence Score   Median Time At Port  \
# False                                           146.0                146.0
# True                                              NaN                  NaN
#
#        Time At Port Confidence Score  \
# False                          146.0
# True                             NaN
#
#        Median Waiting Time Off Port Limits Difference (week-to-week)  \
# False                                                127
# True                                                  19
#
#        Waiting Time Off Port Limits  % Difference (week-to-week)  \
# False                                                129
# True                                                  17
#
#        Time At Port Difference (week-to-week)  \
# ...

# %%
#Replacing nan value with 0
df = df.replace(np.nan,0)

# %%
df.isna().apply(pd.value_counts)
# Out:
#        Port  Year  Week  Median Waiting Time Off Port Limits  \
# False   146   146   146                                  146
#
#        Waiting Time Off Port Limits Confidence Score   Median Time At Port  \
# False                                             146                  146
#
#        Time At Port Confidence Score  \
# False                            146
#
#        Median Waiting Time Off Port Limits Difference (week-to-week)  \
# False                                                146
#
#        Waiting Time Off Port Limits  % Difference (week-to-week)  \
# False                                                146
#
#        Time At Port Difference (week-to-week)  \
# False                                     146
#
#        Time At Port % Difference (week-to-week)  Number Of Calls  \
# False                                       146              146
#
#        Number Of Vessels
# False                146

# %%
#x1 = df.iloc[ :, [0,1,2,4,6,7,8,9,10,11,12,13,14]]

# %%
#y1 = df.iloc[:, [3]]

# %%
#Assigning labels
X = df.iloc[ :, [0,1,2,4,6,7,8,9,10,11,12]]
y = df.iloc[:, [3]]

# %%
X.head(2)
# Out:
#    Port  Year  Week  Waiting Time Off Port Limits Confidence Score   \
# 0     0  2022    24                                               2
# 1     1  2022    24                                               2
#
#    Time At Port Confidence Score  \
# 0                              2
# 1                              2
#
#    Median Waiting Time Off Port Limits Difference (week-to-week)  \
# 0                                               -0.1
# 1                                                0.1
#
#    Waiting Time Off Port Limits  % Difference (week-to-week)  \
# 0                                              -10.0
# 1                                               12.5
#
#    Time At Port Difference (week-to-week)  \
# 0                                     0.0
# 1                                     0.0
#
#    Time At Port % Difference (week-to-week)  Number Of Calls  \
# 0                                       0.0               16
# ...

# %%
y.head(2)
# Out:
#    Median Waiting Time Off Port Limits
# 0                                  0.9
# 1                                  0.9

# %%
X.dtypes
# Out:
# Port                                                               int64
# Year                                                               int64
# Week                                                               int64
# Waiting Time Off Port Limits Confidence Score                      int64
# Time At Port Confidence Score                                      int64
# Median Waiting Time Off Port Limits Difference (week-to-week)    float64
# Waiting Time Off Port Limits  % Difference (week-to-week)        float64
# Time At Port Difference (week-to-week)                           float64
# Time At Port % Difference (week-to-week)                         float64
# Number Of Calls                                                    int64
# Number Of Vessels                                                  int64
# dtype: object

# %%
y.dtypes
# Out:
# Median Waiting Time Off Port Limits    float64
# dtype: object

# %%
y1 = df.iloc[:, [5]]

# %%
y1.head(2)
# Out:
#    Median Time At Port
# 0                  0.0
# 1                  0.8

# %%
#Feature importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
##To plot feature importances
feat_importances=pd.Series(model.feature_importances_,index=X.columns)
feat_importances.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
y_train.dtype
# Out:
# dtype('int64')

# %%
#Assigning training and testing value
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
#Performing scaling using StandardScalar
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaler=sc.fit(X)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
# Supervised Learning technique 

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , confusion_matrix, classification_report

model=LogisticRegression(random_state=1)
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

test_acc=model.score(X_test, y_test)
train_acc=model.score(X_train, y_train)
print('Training Accuracy :',train_acc*100 )
print('\nTest Accuracy :',test_acc*100)

result = pd.DataFrame({'Model' : ['Logistic Regression'], 'train_accuracy' : [train_acc],'test_accuracy' : [test_acc]})

print("\nResult:\n",result)

plt.figure(figsize=(7,6))
plt.title('Model:Logistic Regression')
cm=confusion_matrix(y_pred,y_test)
sns.heatmap(cm,annot=True,fmt='g')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual labels')

print('\nclassification Matrix:\n', classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-ae426a5d19aa> in <module>
#       9 y_pred=model.predict(X_test)
#      10
# ---> 11 test_acc=model.score(X_test, y_test)
#      12 train_acc=model.score(X_train, y_train)
#      13 print('Training Accuracy :',train_acc*100 )
#
# C:\Anaconda\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     664         from .metrics import accuracy_score
#     665
# --> 666         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     667
#     668     def _more_tags(self):
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...

# %%
#Using RandomForestClassifier model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,max_depth=1700,random_state=5)
rf.fit(X_train, y_train)
predict = rf.predict(X_test)

from sklearn import metrics
print('Accuracy :: ',metrics.accuracy_score(y_test,predict))
print('Precision :: ',metrics.precision_score(y_test,predict))
from sklearn.metrics import accuracy_score,confusion_matrix
Rf_cm = confusion_matrix(predict,y_test)
ax = sns.heatmap(Rf_cm,annot=True)
ax.set(xlabel='predict', ylabel='true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-176797e765b9> in <module>
#       6
#       7 from sklearn import metrics
# ----> 8 print('Accuracy :: ',metrics.accuracy_score(y_test,predict))
#       9 print('Precision :: ',metrics.precision_score(y_test,predict))
#      10 from sklearn.metrics import accuracy_score,confusion_matrix
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      91
# ...

# %%
#Hyperparameter tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV
model1 = RandomForestClassifier(n_estimators=50, max_depth=10, max_features='log2')

param_grid = {
    'n_estimators' : [50,1000],
    'max_depth': [1,100],
    'max_features': ['auto', 'sqrt', 'log2'],
    'random_state':[0,1000]
}


CV_rfc = GridSearchCV(estimator=model1, param_grid=param_grid, cv= 5)
CV_rfc.fit(X, y)
print (CV_rfc.best_params_)

# %%
#Using RandomForestClassifier model using the tuned parameters
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000,max_depth=100,random_state=1000,max_features='log2')
rf.fit(X_train, y_train)
predict = rf.predict(X_test)

from sklearn import metrics
print('Accuracy :: ',metrics.accuracy_score(y_test,predict))
print('Precision :: ',metrics.precision_score(y_test,predict))
from sklearn.metrics import accuracy_score,confusion_matrix
Rf_cm = confusion_matrix(predict,y_test)
ax = sns.heatmap(Rf_cm,annot=True)
ax.set(xlabel='predict', ylabel='true')
# Out:
# Accuracy ::  0.9925373134328358
# Precision ::  0.987012987012987
# [Text(33.0, 0.5, 'true'), Text(0.5, 15.0, 'predict')]
